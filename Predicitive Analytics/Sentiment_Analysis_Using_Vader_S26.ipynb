# %% [markdown]
# # Sentiment Analysis - VADER
# * VADER (Valence Aware Dictionary and sEntimnet Reasoner): Is a lexicon and rule-based model for sentiment analysis.
# * Sentiment Analysis:
#     * polarity-based: pieces of texts are classified as either positive or negative
#     * valence-based: intensity of the sentiment is taken into account.
# * VADER:
#     * Each word in the lexico has a sentiment rating
#     * The text is analyzed with four ratings: positive, negative, neutral and compound.
#         * Positive, Negative and Neutral represent the proportion of the text that falls into these categories. They are on the scale from 0 to 1.
#         * Compound is the sum of valence scores of each word in the lexicon determines the degeree of the sentiment and has been standardized to -1 and 1.
#             * Positive sentiment, if compound >= 0.05
#             * Negative sentiment, if compound <=-0.05
#             * Neutral sentiment, if -0.05 < compound < 0.05
#     * VADER takes into account punctuation marks, acronyms and emoticons.
#     * VADER gives a continuous score (-1 to 1), but in machine learning, we often convert it into a `categories (0/1 or 0/1/2)`.
#     * It should be noted that when converting into binary classification, there are two possible compound threshold values:
#         * if compound >= 0:
#                 sentiment = 1
#             else:
#                 sentment = 1
#         * if compound >= 0.05:
#                 sentiment = 1
#             else:
#                 sentiment = 0
#
# * Installation: in Jupyter Notebook, enter "!pip install vaderSentiment"

# %%
# -- import libraries --
import numpy as np
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
# -- instantiate an object --
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# # Simple examples

# %%
# -- sentiment scale --
pos='I like this subject!'
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.518, 'pos': 0.482, 'compound': 0.4199}

# %%
# -- sentiment scale --
pos='I like this subject!!!'
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.471, 'pos': 0.529, 'compound': 0.5229}

# %%
# -- sentiment scale --
pos='I enjoy this subject!!!'
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.424, 'pos': 0.576, 'compound': 0.6219}

# %%
# -- sentiment scale --
pos='I really enjoy this subject!!!'
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.478, 'pos': 0.522, 'compound': 0.6563}

# %%
# -- sentiment scale --
pos='I REALLY enjoy this subject!!!'
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.439, 'pos': 0.561, 'compound': 0.7271}

# %%
# -- sentiment scale --
pos='This subject is just fine.'
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.2023}

# %%
# -- sentiment scale --
pos='This subject is fine.'
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.2023}

# %%
# -- sentiment scale --
pos='This subject is fine, but...'
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.1027}

# %%
pos = "This class is fire."
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.444, 'neu': 0.556, 'pos': 0.0, 'compound': -0.34}

# %% [markdown]
# # Emoticons

# %%
# -- sentiment scale --
pos = "I just got a call from my boss - does he realize it's Saturday?"
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
# -- sentiment scale --
pos = "I just got a call from my boss - does he realize it's Saturday? :("
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.172, 'neu': 0.828, 'pos': 0.0, 'compound': -0.4404}

# %%
# -- sentiment scale --
pos = "I just got a call from my boss - does he realize it's Saturday? :)"
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.824, 'pos': 0.176, 'compound': 0.4588}

# %%
# -- sentiment scale --
pos = "I just got a call from my boss - does he realize it's Saturday? smh :("
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.141, 'neu': 0.859, 'pos': 0.0, 'compound': -0.3182}

# %% [markdown]
# # Qualifying
#
# **See how capitals affect the evaluation of sentiment**

# %%
# -- sentiment scale --
pos = "The movie is good."
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}

# %%
# -- sentiment scale --
pos = "The movie is GOOD."
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.452, 'pos': 0.548, 'compound': 0.5622}

# %%
# -- sentiment scale --
pos = "The movie is GOOD!"
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.433, 'pos': 0.567, 'compound': 0.6027}

# %%
# -- sentiment scale --
pos = "The movie is GOOD!!!"
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.4, 'pos': 0.6, 'compound': 0.6714}

# %%
# -- sentiment scale --
pos = "The movie is GREAT!!!"
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.344, 'pos': 0.656, 'compound': 0.7723}

# %%
# -- sentiment scale --
pos = "The movie is really good."
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.4927}

# %%
# -- sentiment scale --
pos = "The movie is really good!"
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.534, 'pos': 0.466, 'compound': 0.54}

# %%
# -- sentiment scale --
pos = "The movie is really GOOD!"
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.0, 'neu': 0.487, 'pos': 0.513, 'compound': 0.6391}

# %% [markdown]
# # BUT: The sentiment after BUT is weighted more than that before.

# %%
# -- sentiment scale --
pos = "The movie is really GOOD! But the theater is dreadful."
analyzer.polarity_scores(pos)
# Out:
# {'neg': 0.284, 'neu': 0.548, 'pos': 0.169, 'compound': -0.3977}

# %% [markdown]
# # Exercises
#
# **Create a few sentences with qualifying adverbs or adjective, and emoticons**
